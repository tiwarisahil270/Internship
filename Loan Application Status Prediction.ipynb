# %% [markdown]
# Importing the libararies

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('https://raw.githubusercontent.com/dsrscientist/DSData/master/loan_prediction.csv')
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %% [markdown]
# Observation- The dataset contains 614 rows and 13 columns, The loan_status is "y" or  "n" hence we will apply Logistic Regression here, also some value of the dataset is not numeric, first we will convert that values in numerical format which will be easy to analyse

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
df['Loan_Status']=le.fit_transform(df['Loan_Status'])

# %%
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df.Property_Area.value_counts()
# Out:
# Semiurban    233
# Urban        202
# Rural        179
# Name: Property_Area, dtype: int64

# %%
print(df['Property_Area'].value_counts())
sns.countplot(df['Property_Area'],palette="cool")
# Out:
# Semiurban    233
# Urban        202
# Rural        179
# Name: Property_Area, dtype: int64
# <AxesSubplot:xlabel='Property_Area', ylabel='count'>

# %%
df['Property_Area']=le.fit_transform(df['Property_Area'])

# %%
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df.dtypes
# Out:
# Loan_ID               object
# Gender                object
# Married               object
# Dependents            object
# Education             object
# Self_Employed         object
# ApplicantIncome        int64
# CoapplicantIncome    float64
# LoanAmount           float64
# Loan_Amount_Term     float64
# Credit_History       float64
# Property_Area          int32
# Loan_Status            int32
# dtype: object

# %% [markdown]
# Dependents is showing object

# %%
df.Dependents.value_counts()
# Out:
# 0     345
# 1     102
# 2     101
# 3+     51
# Name: Dependents, dtype: int64

# %%
print(df['Dependents'].value_counts())
sns.countplot(df['Dependents'],palette="cool")
# Out:
# 0     345
# 1     102
# 2     101
# 3+     51
# Name: Dependents, dtype: int64
# <AxesSubplot:xlabel='Dependents', ylabel='count'>

# %%
df['Dependents']=le.fit_transform(df['Dependents'])

# %%
df
# Out:
#       Loan_ID  Gender Married  Dependents     Education Self_Employed  \
# 0    LP001002    Male      No           0      Graduate            No
# 1    LP001003    Male     Yes           1      Graduate            No
# 2    LP001005    Male     Yes           0      Graduate           Yes
# 3    LP001006    Male     Yes           0  Not Graduate            No
# 4    LP001008    Male      No           0      Graduate            No
# ..        ...     ...     ...         ...           ...           ...
# 609  LP002978  Female      No           0      Graduate            No
# 610  LP002979    Male     Yes           3      Graduate            No
# 611  LP002983    Male     Yes           1      Graduate            No
# 612  LP002984    Male     Yes           2      Graduate            No
# 613  LP002990  Female      No           0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df.dtypes
# Out:
# Loan_ID               object
# Gender                object
# Married               object
# Dependents             int32
# Education             object
# Self_Employed         object
# ApplicantIncome        int64
# CoapplicantIncome    float64
# LoanAmount           float64
# Loan_Amount_Term     float64
# Credit_History       float64
# Property_Area          int32
# Loan_Status            int32
# dtype: object

# %%
df.Education.value_counts()
# Out:
# Graduate        480
# Not Graduate    134
# Name: Education, dtype: int64

# %%
print(df['Education'].value_counts())
sns.countplot(df['Education'],palette="cool")
# Out:
# Graduate        480
# Not Graduate    134
# Name: Education, dtype: int64
# <AxesSubplot:xlabel='Education', ylabel='count'>

# %%
df['Education']=le.fit_transform(df['Education'])

# %%
df
# Out:
#       Loan_ID  Gender Married  Dependents  Education Self_Employed  \
# 0    LP001002    Male      No           0          0            No
# 1    LP001003    Male     Yes           1          0            No
# 2    LP001005    Male     Yes           0          0           Yes
# 3    LP001006    Male     Yes           0          1            No
# 4    LP001008    Male      No           0          0            No
# ..        ...     ...     ...         ...        ...           ...
# 609  LP002978  Female      No           0          0            No
# 610  LP002979    Male     Yes           3          0            No
# 611  LP002983    Male     Yes           1          0            No
# 612  LP002984    Male     Yes           2          0            No
# 613  LP002990  Female      No           0          0           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5849                0.0         NaN             360.0
# ...

# %%
df.Married.value_counts()
# Out:
# Yes    398
# No     213
# Name: Married, dtype: int64

# %%
print(df['Married'].value_counts())
sns.countplot(df['Married'],palette="cool")
# Out:
# Yes    398
# No     213
# Name: Married, dtype: int64
# <AxesSubplot:xlabel='Married', ylabel='count'>

# %%
df['Married']=le.fit_transform(df['Married'])

# %%
df
# Out:
#       Loan_ID  Gender  Married  Dependents  Education Self_Employed  \
# 0    LP001002    Male        0           0          0            No
# 1    LP001003    Male        1           1          0            No
# 2    LP001005    Male        1           0          0           Yes
# 3    LP001006    Male        1           0          1            No
# 4    LP001008    Male        0           0          0            No
# ..        ...     ...      ...         ...        ...           ...
# 609  LP002978  Female        0           0          0            No
# 610  LP002979    Male        1           3          0            No
# 611  LP002983    Male        1           1          0            No
# 612  LP002984    Male        1           2          0            No
# 613  LP002990  Female        0           0          0           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5849                0.0         NaN             360.0
# ...

# %%
df.drop('Loan_ID', axis=1, inplace=True)

# %%
df['Gender']=le.fit_transform(df['Gender'])

# %%
df
# Out:
#      Gender  Married  Dependents  Education Self_Employed  ApplicantIncome  \
# 0         1        0           0          0            No             5849
# 1         1        1           1          0            No             4583
# 2         1        1           0          0           Yes             3000
# 3         1        1           0          1            No             2583
# 4         1        0           0          0            No             6000
# ..      ...      ...         ...        ...           ...              ...
# 609       0        0           0          0            No             2900
# 610       1        1           3          0            No             4106
# 611       1        1           1          0            No             8072
# 612       1        1           2          0            No             7583
# 613       0        0           0          0           Yes             4583
#
# ...

# %%
df.Self_Employed.value_counts()
# Out:
# No     500
# Yes     82
# Name: Self_Employed, dtype: int64

# %%
print(df['Self_Employed'].value_counts())
sns.countplot(df['Self_Employed'], palette="cool")
# Out:
# No     500
# Yes     82
# Name: Self_Employed, dtype: int64
# <AxesSubplot:xlabel='Self_Employed', ylabel='count'>

# %%
df['Self_Employed']=le.fit_transform(df['Self_Employed'])

# %%
df
# Out:
#      Gender  Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 0         1        0           0          0              0             5849
# 1         1        1           1          0              0             4583
# 2         1        1           0          0              1             3000
# 3         1        1           0          1              0             2583
# 4         1        0           0          0              0             6000
# ..      ...      ...         ...        ...            ...              ...
# 609       0        0           0          0              0             2900
# 610       1        1           3          0              0             4106
# 611       1        1           1          0              0             8072
# 612       1        1           2          0              0             7583
# 613       0        0           0          0              1             4583
#
# ...

# %%
df.dtypes
# Out:
# Gender                 int32
# Married                int32
# Dependents             int32
# Education              int32
# Self_Employed          int32
# ApplicantIncome        int64
# CoapplicantIncome    float64
# LoanAmount           float64
# Loan_Amount_Term     float64
# Credit_History       float64
# Property_Area          int32
# Loan_Status            int32
# dtype: object

# %%
df.isnull().sum()
# Out:
# Gender                0
# Married               0
# Dependents            0
# Education             0
# Self_Employed         0
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %% [markdown]
# There are som NaN value is "LoanAmount","Loan_Amount_Term","Credit_History", Still we will check it in Heat map to confirm the same

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# Hence we can see that there are null values present in above mentioned rows

# %% [markdown]
# In place of removing NaN values we will replace it by mean with the help of Numpy Liberary

# %%
import numpy as np

# %% [markdown]
# df['LoanAmount'].replace(np.NaN,df['LoanAmount'].mean,inplace=True)

# %% [markdown]
# df['Loan_Amount_Term'].replace(np.NaN,df['Loan_Amount_Term'].mean,inplace=True)

# %% [markdown]
# df['Credit_History'].replace(np.NaN,df['Credit_History'].mean,inplace=True)

# %% [markdown]
# The Kernel is geeting dea if we replace NaN by mean. finding alternate ways

# %%
df.isnull().sum()
# Out:
# Gender                0
# Married               0
# Dependents            0
# Education             0
# Self_Employed         0
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Gender             614 non-null    int32
#  1   Married            614 non-null    int32
#  2   Dependents         614 non-null    int32
#  3   Education          614 non-null    int32
#  4   Self_Employed      614 non-null    int32
#  5   ApplicantIncome    614 non-null    int64
#  6   CoapplicantIncome  614 non-null    float64
#  7   LoanAmount         592 non-null    float64
#  8   Loan_Amount_Term   600 non-null    float64
#  9   Credit_History     564 non-null    float64
#  10  Property_Area      614 non-null    int32
#  11  Loan_Status        614 non-null    int32
# dtypes: float64(4), int32(7), int64(1)
# memory usage: 40.9 KB

# %%
df.min()
# Out:
# Gender                 0.0
# Married                0.0
# Dependents             0.0
# Education              0.0
# Self_Employed          0.0
# ApplicantIncome      150.0
# CoapplicantIncome      0.0
# LoanAmount             9.0
# Loan_Amount_Term      12.0
# Credit_History         0.0
# Property_Area          0.0
# Loan_Status            0.0
# dtype: float64

# %%
df.max()
# Out:
# Gender                   2.0
# Married                  2.0
# Dependents               4.0
# Education                1.0
# Self_Employed            2.0
# ApplicantIncome      81000.0
# CoapplicantIncome    41667.0
# LoanAmount             700.0
# Loan_Amount_Term       480.0
# Credit_History           1.0
# Property_Area            2.0
# Loan_Status              1.0
# dtype: float64

# %%
df.head()
# Out:
#    Gender  Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 0       1        0           0          0              0             5849
# 1       1        1           1          0              0             4583
# 2       1        1           0          0              1             3000
# 3       1        1           0          1              0             2583
# 4       1        0           0          0              0             6000
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0                0.0         NaN             360.0             1.0
# 1             1508.0       128.0             360.0             1.0
# 2                0.0        66.0             360.0             1.0
# 3             2358.0       120.0             360.0             1.0
# 4                0.0       141.0             360.0             1.0
#
#    Property_Area  Loan_Status
# 0              2            1
# 1              0            0
# ...

# %%
df.tail()
# Out:
#      Gender  Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 609       0        0           0          0              0             2900
# 610       1        1           3          0              0             4106
# 611       1        1           1          0              0             8072
# 612       1        1           2          0              0             7583
# 613       0        0           0          0              1             4583
#
#      CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 609                0.0        71.0             360.0             1.0
# 610                0.0        40.0             180.0             1.0
# 611              240.0       253.0             360.0             1.0
# 612                0.0       187.0             360.0             1.0
# 613                0.0       133.0             360.0             0.0
#
#      Property_Area  Loan_Status
# 609              0            1
# ...

# %%
df.isnull().sum()
# Out:
# Gender                0
# Married               0
# Dependents            0
# Education             0
# Self_Employed         0
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
df.dropna(inplace= True)

# %%
df
# Out:
#      Gender  Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 1         1        1           1          0              0             4583
# 2         1        1           0          0              1             3000
# 3         1        1           0          1              0             2583
# 4         1        0           0          0              0             6000
# 5         1        1           2          0              1             5417
# ..      ...      ...         ...        ...            ...              ...
# 609       0        0           0          0              0             2900
# 610       1        1           3          0              0             4106
# 611       1        1           1          0              0             8072
# 612       1        1           2          0              0             7583
# 613       0        0           0          0              1             4583
#
# ...

# %%
df.shape
# Out:
# (529, 12)

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# As we can see there is no null value present in the given dataset

# %%
df.describe()
# Out:
#            Gender     Married  Dependents   Education  Self_Employed  \
# count  529.000000  529.000000  529.000000  529.000000     529.000000
# mean     0.843100    0.648393    0.854442    0.204159       0.226843
# std      0.421885    0.485785    1.121241    0.403467       0.520014
# min      0.000000    0.000000    0.000000    0.000000       0.000000
# 25%      1.000000    0.000000    0.000000    0.000000       0.000000
# 50%      1.000000    1.000000    0.000000    0.000000       0.000000
# 75%      1.000000    1.000000    2.000000    0.000000       0.000000
# max      2.000000    2.000000    4.000000    1.000000       2.000000
#
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       529.000000         529.000000  529.000000        529.000000
# mean       5507.822306        1542.394934  145.852552        342.351607
# std        6404.132369        2524.295797   84.108409         64.861662
# ...

# %% [markdown]
# Observations :- Standard Deviation is high in "ApplicantIncome","CoapplicantIncome","LoanAmount","Loan_Amount_Term" hence there is the possibilities of Outliers in this columns
#
# mean>median in "ApplicantIncome", "CoapplicantIncome" ,column hence there is a possibilities of skewness in the data
#
# There is a high difference in 75% and max value hence there is a possibility of outliers in "ApplicantIncome", "CoapplicantIncome","LoanAmount", "Loan_Amount_Term" columns

# %%
dfcor=df.corr()
dfcor
# Out:
#                      Gender   Married  Dependents  Education  Self_Employed  \
# Gender             1.000000  0.330988    0.179846   0.032770      -0.036017
# Married            0.330988  1.000000    0.354413   0.009407      -0.036041
# Dependents         0.179846  0.354413    1.000000   0.040694      -0.004980
# Education          0.032770  0.009407    0.040694   1.000000       0.013549
# Self_Employed     -0.036017 -0.036041   -0.004980   0.013549       1.000000
# ApplicantIncome    0.091801  0.051737    0.106932  -0.132015       0.110006
# CoapplicantIncome  0.130529  0.110537   -0.019422  -0.060520      -0.019479
# LoanAmount         0.138067  0.172137    0.158508  -0.169390       0.064810
# Loan_Amount_Term  -0.080620 -0.089838   -0.054452  -0.080910      -0.039429
# Credit_History    -0.004971  0.013366   -0.082853  -0.064098       0.050234
# Property_Area     -0.019791  0.022623    0.040056  -0.078661      -0.066773
# ...

# %%
sns.heatmap(dfcor)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(20,15))
sns.heatmap(dfcor,cmap='Blues',fmt=".1g",annot= True)
plt.yticks(rotation=0);
plt.show()

# %% [markdown]
# As we can see fro correlation table "Credit History", "ApplicantIncome" are highly correleated with "Loan Status"

# %%
sns.pairplot(df,hue="Loan_Status",palette="Dark2")
plt.show()

# %%
df.plot(kind='box',subplots=True,layout=(4,5),figsize=(12,8))
# Out:
# Gender                  AxesSubplot(0.125,0.712609;0.133621x0.167391)
# Married              AxesSubplot(0.285345,0.712609;0.133621x0.167391)
# Dependents            AxesSubplot(0.44569,0.712609;0.133621x0.167391)
# Education            AxesSubplot(0.606034,0.712609;0.133621x0.167391)
# Self_Employed        AxesSubplot(0.766379,0.712609;0.133621x0.167391)
# ApplicantIncome         AxesSubplot(0.125,0.511739;0.133621x0.167391)
# CoapplicantIncome    AxesSubplot(0.285345,0.511739;0.133621x0.167391)
# LoanAmount            AxesSubplot(0.44569,0.511739;0.133621x0.167391)
# Loan_Amount_Term     AxesSubplot(0.606034,0.511739;0.133621x0.167391)
# Credit_History       AxesSubplot(0.766379,0.511739;0.133621x0.167391)
# Property_Area            AxesSubplot(0.125,0.31087;0.133621x0.167391)
# Loan_Status           AxesSubplot(0.285345,0.31087;0.133621x0.167391)
# dtype: object

# %% [markdown]
# There are some outliers present every columns except "property_Area", "Married", "Dependents"

# %% [markdown]
# Removing the outliers

# %%
from scipy.stats import zscore
out_features=df[['Education','Self_Employed','ApplicantIncome','CoapplicantIncome','LoanAmount','Loan_Amount_Term','Credit_History']]
z=np.abs(zscore(out_features))
z
# Out:
#      Education  Self_Employed  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# 1     0.506490       0.436638         0.144547           0.013638    0.212457
# 2     0.506490       1.488208         0.391965           0.611598    0.950299
# 3     1.974373       0.436638         0.457141           0.323408    0.307663
# 4     0.506490       0.436638         0.076926           0.611598    0.057749
# 5     0.506490       1.488208         0.014195           1.052221    1.441736
# ..         ...            ...              ...                ...         ...
# 609   0.506490       0.436638         0.407595           0.611598    0.890796
# 610   0.506490       0.436638         0.219101           0.611598    1.259716
# 611   0.506490       0.436638         0.400773           0.516432    1.275127
# 612   0.506490       0.436638         0.324344           0.611598    0.489682
# 613   0.506490       1.488208         0.144547           0.611598    0.152954
#
# ...

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([  8,  10,  13,  25,  57,  78,  88,  92,  93, 107, 129, 129, 131,
#        142, 143, 143, 149, 149, 154, 156, 185, 196, 204, 222, 228, 238,
#        253, 265, 284, 284, 284, 286, 293, 315, 320, 325, 330, 344, 351,
#        358, 371, 371, 380, 383, 396, 401, 418, 424, 449, 450, 458, 465,
#        468, 480, 493, 497, 499, 502, 517, 520], dtype=int64), array([3, 1, 5, 1, 5, 5, 1, 1, 1, 5, 2, 4, 1, 1, 2, 4, 3, 4, 2, 2, 1, 1,
#        5, 5, 1, 4, 1, 4, 1, 2, 4, 1, 1, 4, 1, 1, 1, 3, 2, 3, 1, 4, 2, 1,
#        1, 1, 4, 5, 4, 4, 1, 1, 5, 4, 5, 1, 3, 5, 1, 4], dtype=int64))

# %%
df_new=df[(z<3).all(axis=1)]
df_new
# Out:
#      Gender  Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 1         1        1           1          0              0             4583
# 2         1        1           0          0              1             3000
# 3         1        1           0          1              0             2583
# 4         1        0           0          0              0             6000
# 5         1        1           2          0              1             5417
# ..      ...      ...         ...        ...            ...              ...
# 609       0        0           0          0              0             2900
# 610       1        1           3          0              0             4106
# 611       1        1           1          0              0             8072
# 612       1        1           2          0              0             7583
# 613       0        0           0          0              1             4583
#
# ...

# %%
df_new.shape
# Out:
# (475, 12)

# %%
df=df_new
df
# Out:
#      Gender  Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 1         1        1           1          0              0             4583
# 2         1        1           0          0              1             3000
# 3         1        1           0          1              0             2583
# 4         1        0           0          0              0             6000
# 5         1        1           2          0              1             5417
# ..      ...      ...         ...        ...            ...              ...
# 609       0        0           0          0              0             2900
# 610       1        1           3          0              0             4106
# 611       1        1           1          0              0             8072
# 612       1        1           2          0              0             7583
# 613       0        0           0          0              1             4583
#
# ...

# %% [markdown]
# Checking for Skewness

# %%
df.skew()
# Out:
# Gender              -0.930817
# Married             -0.522400
# Dependents           1.077335
# Education            1.440267
# Self_Employed        2.173108
# ApplicantIncome      2.206392
# CoapplicantIncome    1.406969
# LoanAmount           1.126810
# Loan_Amount_Term    -1.937693
# Credit_History      -1.882338
# Property_Area       -0.044180
# Loan_Status         -0.826909
# dtype: float64

# %% [markdown]
# The data must fall in the range of -0.5 to +0.5 Above it is the skewness

# %%
df['ApplicantIncome']=np.cbrt(df['ApplicantIncome'])

# %%
df.skew()
# Out:
# Gender              -0.930817
# Married             -0.522400
# Dependents           1.077335
# Education            1.440267
# Self_Employed        2.173108
# ApplicantIncome      0.923550
# CoapplicantIncome    1.406969
# LoanAmount           1.126810
# Loan_Amount_Term    -1.937693
# Credit_History      -1.882338
# Property_Area       -0.044180
# Loan_Status         -0.826909
# dtype: float64

# %%
df['Self_Employed']=np.cbrt(df['Self_Employed'])

# %%
df.skew()
# Out:
# Gender              -0.930817
# Married             -0.522400
# Dependents           1.077335
# Education            1.440267
# Self_Employed        2.173108
# ApplicantIncome      0.923550
# CoapplicantIncome    1.406969
# LoanAmount           1.126810
# Loan_Amount_Term    -1.937693
# Credit_History      -1.882338
# Property_Area       -0.044180
# Loan_Status         -0.826909
# dtype: float64

# %% [markdown]
# Skewness is removed from the given dataset

# %%
df.corr()
# Out:
#                      Gender   Married  Dependents  Education  Self_Employed  \
# Gender             1.000000  0.345730    0.189421   0.039674       0.024860
# Married            0.345730  1.000000    0.346450   0.027731      -0.012568
# Dependents         0.189421  0.346450    1.000000   0.057079       0.020990
# Education          0.039674  0.027731    0.057079   1.000000      -0.001995
# Self_Employed      0.024860 -0.012568    0.020990  -0.001995       1.000000
# ApplicantIncome    0.051281 -0.022719    0.111983  -0.167417       0.260154
# CoapplicantIncome  0.171944  0.225228   -0.021406  -0.041630      -0.032939
# LoanAmount         0.168623  0.174032    0.150099  -0.160621       0.135647
# Loan_Amount_Term  -0.104204 -0.127597   -0.051624  -0.091875      -0.050001
# Credit_History     0.006512  0.033168   -0.054682  -0.076308      -0.017918
# Property_Area     -0.026675  0.028835    0.021195  -0.069694      -0.044442
# ...

# %%
x=df.drop("Loan_Status", axis = 1)
y=df["Loan_Status"]

# %%
x
# Out:
#      Gender  Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 1         1        1           1          0            0.0        16.610522
# 2         1        1           0          0            1.0        14.422496
# 3         1        1           0          1            0.0        13.720654
# 4         1        0           0          0            0.0        18.171206
# 5         1        1           2          0            1.0        17.562498
# ..      ...      ...         ...        ...            ...              ...
# 609       0        0           0          0            0.0        14.260431
# 610       1        1           3          0            0.0        16.013010
# 611       1        1           1          0            0.0        20.059821
# 612       1        1           2          0            0.0        19.646281
# 613       0        0           0          0            1.0        16.610522
#
# ...

# %%
y
# Out:
# 1      0
# 2      1
# 3      1
# 4      1
# 5      1
#       ..
# 609    1
# 610    1
# 611    1
# 612    1
# 613    0
# Name: Loan_Status, Length: 475, dtype: int32

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x=pd.DataFrame(scaler.fit_transform(x),columns=x.columns)
x
# Out:
#        Gender   Married  Dependents  Education  Self_Employed  \
# 0    0.365934  0.719742    0.138101  -0.513126       -0.39104
# 1    0.365934  0.719742   -0.748358  -0.513126        2.55728
# 2    0.365934  0.719742   -0.748358   1.948841       -0.39104
# 3    0.365934 -1.339760   -0.748358  -0.513126       -0.39104
# 4    0.365934  0.719742    1.024560  -0.513126        2.55728
# ..        ...       ...         ...        ...            ...
# 470 -2.015145 -1.339760   -0.748358  -0.513126       -0.39104
# 471  0.365934  0.719742    1.911020  -0.513126       -0.39104
# 472  0.365934  0.719742    0.138101  -0.513126       -0.39104
# 473  0.365934  0.719742    1.024560  -0.513126       -0.39104
# 474 -2.015145 -1.339760   -0.748358  -0.513126        2.55728
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0           0.110125           0.070323   -0.157491          0.224024
# 1          -0.594074          -0.842214   -1.205417          0.224024
# ...

# %% [markdown]
# Checking the multicolinearity of the data, if not necessary we can remove the data too, but removing the data may lead to loss of information, hence we will not dro any columns as all are under control

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=pd.DataFrame()
vif["VIF values"]=[variance_inflation_factor(x.values,i)
                  for i in range(len(x.columns))]
vif["Features"]=x.columns
vif
# Out:
#     VIF values           Features
# 0     1.174670             Gender
# 1     1.337917            Married
# 2     1.192092         Dependents
# 3     1.075648          Education
# 4     1.079861      Self_Employed
# 5     1.919356    ApplicantIncome
# 6     1.538232  CoapplicantIncome
# 7     1.936540         LoanAmount
# 8     1.072578   Loan_Amount_Term
# 9     1.020459     Credit_History
# 10    1.030403      Property_Area

# %%
from sklearn.ensemble import RandomForestClassifier,ExtraTreesClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import GradientBoostingClassifier,AdaBoostClassifier,BaggingClassifier
from sklearn.metrics import classification_report,confusion_matrix,roc_curve,accuracy_score
from sklearn.model_selection import cross_val_score

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier 
from sklearn.metrics import accuracy_score
maxAccu = 0 
maxRS = 0
for i in range(1,200):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=i)
    RFR =RandomForestClassifier()
    RFR.fit(x_train,y_train)
    pred=RFR.predict(x_test)
    acc=accuracy_score(y_test,pred)
    if acc>maxAccu:
        maxAccu=acc
        maxRS=i
        
print("Best accuracy is",maxAccu,"at random_state",maxRS)
# Out:
# Best accuracy is 0.8601398601398601 at random_state 22

# %% [markdown]
# Spliting the data in x_train,x_test and y_train,y_test

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=maxRS)

# %%
from sklearn.ensemble import RandomForestClassifier,ExtraTreesClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import GradientBoostingClassifier,AdaBoostClassifier,BaggingClassifier
from sklearn.metrics import classification_report,confusion_matrix,roc_curve,accuracy_score
from sklearn.model_selection import cross_val_score

# %%
RFC= RandomForestClassifier()
RFC.fit(x_train,y_train)
predRFC = RFC.predict(x_test)
print(accuracy_score(y_test,predRFC))
print(confusion_matrix(y_test,predRFC))
print(classification_report(y_test,predRFC))
# Out:
# 0.8601398601398601
# [[26 18]
#  [ 2 97]]
#               precision    recall  f1-score   support
#
#            0       0.93      0.59      0.72        44
#            1       0.84      0.98      0.91        99
#
#     accuracy                           0.86       143
#    macro avg       0.89      0.79      0.81       143
# weighted avg       0.87      0.86      0.85       143

# %% [markdown]
# Accuracy- 86.01%

# %%
LR= LogisticRegression()
LR.fit(x_train,y_train)
predLR=LR.predict(x_test)
print(accuracy_score(y_test,predLR))
print(confusion_matrix(y_test,predLR))
print(classification_report(y_test,predLR))
# Out:
# 0.8531468531468531
# [[24 20]
#  [ 1 98]]
#               precision    recall  f1-score   support
#
#            0       0.96      0.55      0.70        44
#            1       0.83      0.99      0.90        99
#
#     accuracy                           0.85       143
#    macro avg       0.90      0.77      0.80       143
# weighted avg       0.87      0.85      0.84       143

# %% [markdown]
# Accuracy- 85.31%

# %%
svc= SVC()
svc.fit(x_train,y_train)
predsvc=svc.predict(x_test)
print(accuracy_score(y_test,predsvc))
print(confusion_matrix(y_test,predsvc))
print(classification_report(y_test,predsvc))
# Out:
# 0.8461538461538461
# [[23 21]
#  [ 1 98]]
#               precision    recall  f1-score   support
#
#            0       0.96      0.52      0.68        44
#            1       0.82      0.99      0.90        99
#
#     accuracy                           0.85       143
#    macro avg       0.89      0.76      0.79       143
# weighted avg       0.87      0.85      0.83       143

# %% [markdown]
# Accuracy-84.61%

# %%
GB= GradientBoostingClassifier()
GB.fit(x_train,y_train)
predGB=GB.predict(x_test)
print(accuracy_score(y_test,predGB))
print(confusion_matrix(y_test,predGB))
print(classification_report(y_test,predGB))
# Out:
# 0.8321678321678322
# [[24 20]
#  [ 4 95]]
#               precision    recall  f1-score   support
#
#            0       0.86      0.55      0.67        44
#            1       0.83      0.96      0.89        99
#
#     accuracy                           0.83       143
#    macro avg       0.84      0.75      0.78       143
# weighted avg       0.84      0.83      0.82       143

# %% [markdown]
# Accuracy-83.21%

# %%
from sklearn.model_selection import cross_val_score

# %%
score=cross_val_score(RFC,x,y)
print(score)
print(score.mean())
print("The difference between accuracy score and cross validation score is - ",accuracy_score(y_test,predRFC)- score.mean())
# Out:
# [0.82105263 0.75789474 0.81052632 0.82105263 0.84210526]
# 0.8105263157894737
# The difference between accuracy score and cross validation score is -  0.04961354435038645

# %%
score=cross_val_score(LR,x,y)
print(score)
print(score.mean())
print("The difference between accuracy score and cross validation score is - ",accuracy_score(y_test,predLR)- score.mean())
# Out:
# [0.81052632 0.77894737 0.78947368 0.86315789 0.85263158]
# 0.8189473684210526
# The difference between accuracy score and cross validation score is -  0.03419948472580048

# %%
score=cross_val_score(svc,x,y)
print(score)
print(score.mean())
print("The difference between accuracy score and cross validation score is - ",accuracy_score(y_test,predRFC)- score.mean())
# Out:
# [0.82105263 0.77894737 0.78947368 0.84210526 0.86315789]
# 0.8189473684210526
# The difference between accuracy score and cross validation score is -  0.041192491718807456

# %%
score=cross_val_score(GB,x,y)
print(score)
print(score.mean())
print("The difference between accuracy score and cross validation score is - ",accuracy_score(y_test,predRFC)- score.mean())
# Out:
# [0.74736842 0.71578947 0.77894737 0.82105263 0.82105263]
# 0.7768421052631579
# The difference between accuracy score and cross validation score is -  0.08329775487670221

# %% [markdown]
# # Result: We will consider Random Forest Classifier because the accuracy is 86.01%
