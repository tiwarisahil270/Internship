# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt 
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('https://raw.githubusercontent.com/dsrscientist/dataset1/master/titanic_train.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# Observation :- As we can see in this heatmap, there are some "NaN" values or missing values in "Age" and "Cabin" column
#
# Hence we have to remove this missing or NaN values. In age columns there are not much NaN values hence we can do "mean" in "age" and we can remove NaN values in "Cabin" column as there are many missing or NaN values.

# %%
import numpy as np

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
df.Embarked.value_counts()
# Out:
# S    116
# C     65
# Q      2
# Name: Embarked, dtype: int64

# %%
print(df['Embarked'].value_counts())
sns.countplot(df['Embarked'],palette="cool")
# Out:
# S    116
# C     65
# Q      2
# Name: Embarked, dtype: int64
# <AxesSubplot:xlabel='Embarked', ylabel='count'>

# %%
df.shape
# Out:
# (183, 12)

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 183 entries, 1 to 889
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  183 non-null    int64
#  1   Survived     183 non-null    int64
#  2   Pclass       183 non-null    int64
#  3   Name         183 non-null    object
#  4   Sex          183 non-null    object
#  5   Age          183 non-null    float64
#  6   SibSp        183 non-null    int64
#  7   Parch        183 non-null    int64
#  8   Ticket       183 non-null    object
#  9   Fare         183 non-null    float64
#  10  Cabin        183 non-null    object
#  11  Embarked     183 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 18.6+ KB

# %%
df.head(10)
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 3             4         1       1
# 6             7         0       1
# 10           11         1       3
# 11           12         1       1
# 21           22         1       2
# 23           24         1       1
# 27           28         0       1
# 52           53         1       1
# 54           55         0       1
#
#                                                  Name     Sex   Age  SibSp  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
# 21                              Beesley, Mr. Lawrence    male  34.0      0
# ...

# %%
df.tail(10)
# Out:
#      PassengerId  Survived  Pclass  \
# 835          836         1       1
# 853          854         1       1
# 857          858         1       1
# 862          863         1       1
# 867          868         0       1
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 835                        Compton, Miss. Sara Rebecca  female  39.0      1
# 853                          Lines, Miss. Mary Conover  female  16.0      0
# 857                             Daly, Mr. Peter Denis     male  51.0      0
# 862  Swift, Mrs. Frederick Joel (Margaret Welles Ba...  female  48.0      0
# 867               Roebling, Mr. Washington Augustus II    male  31.0      0
# 871   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female  47.0      1
# ...

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   183.000000  183.000000  183.000000  183.000000  183.000000
# mean    455.366120    0.672131    1.191257   35.674426    0.464481
# std     247.052476    0.470725    0.515187   15.643866    0.644159
# min       2.000000    0.000000    1.000000    0.920000    0.000000
# 25%     263.500000    0.000000    1.000000   24.000000    0.000000
# 50%     457.000000    1.000000    1.000000   36.000000    0.000000
# 75%     676.000000    1.000000    1.000000   47.500000    1.000000
# max     890.000000    1.000000    3.000000   80.000000    3.000000
#
#             Parch        Fare
# count  183.000000  183.000000
# mean     0.475410   78.682469
# std      0.754617   76.347843
# min      0.000000    0.000000
# 25%      0.000000   29.700000
# 50%      0.000000   57.000000
# 75%      1.000000   90.000000
# max      4.000000  512.329200

# %% [markdown]
# Observations :- Standard Deviation is high in "Fare" hence there is the possibilities of Outliers in this columns
#
# mean>median in"Fare" column hence there is a possibilities of skewness in the data
#
# There is a high difference in 75% and max value hence there is a possibility of outliers in "Age", "Fare" columns

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %% [markdown]
# dfcor=df.corr()
# dfcor

# %%
sns.heatmap(dfcor)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Observation : - There is a slightly corelation between "survived" and "Fare"

# %%
plt.figure(figsize=(20,15))
sns.heatmap(dfcor,cmap='Blues',fmt=".1g",annot=True)
plt.yticks(rotation=0);
plt.show()

# %%
sns.pairplot(df,hue="Embarked", palette= "Dark2")
plt.show()

# %% [markdown]
# # Checking for Outliers

# %%
df.plot(kind='box',subplots=True,layout=(2,7),figsize=(10,10))
# Out:
# PassengerId       AxesSubplot(0.125,0.53;0.0945122x0.35)
# Survived       AxesSubplot(0.238415,0.53;0.0945122x0.35)
# Pclass         AxesSubplot(0.351829,0.53;0.0945122x0.35)
# Age            AxesSubplot(0.465244,0.53;0.0945122x0.35)
# SibSp          AxesSubplot(0.578659,0.53;0.0945122x0.35)
# Parch          AxesSubplot(0.692073,0.53;0.0945122x0.35)
# Fare           AxesSubplot(0.805488,0.53;0.0945122x0.35)
# dtype: object

# %%
df['Sex'].replace(['male','female'],[0,1],inplace=True)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name  Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...    1  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)    1  35.0      1
# 6                              McCarthy, Mr. Timothy J    0  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut    1   4.0      1
# 11                            Bonnell, Miss. Elizabeth    1  58.0      0
# ..                                                 ...  ...   ...    ...
# ...

# %% [markdown]
# Observation :- As we can see there are some outliers present in "Fare","Pclass","SibSp","Parch"

# %%
df= df.drop(columns=['Name'])

# %%
df
# Out:
#      PassengerId  Survived  Pclass  Sex   Age  SibSp  Parch    Ticket  \
# 1              2         1       1    1  38.0      1      0  PC 17599
# 3              4         1       1    1  35.0      1      0    113803
# 6              7         0       1    0  54.0      0      0     17463
# 10            11         1       3    1   4.0      1      1   PP 9549
# 11            12         1       1    1  58.0      0      0    113783
# ..           ...       ...     ...  ...   ...    ...    ...       ...
# 871          872         1       1    1  47.0      1      1     11751
# 872          873         0       1    0  33.0      0      0       695
# 879          880         1       1    1  56.0      0      1     11767
# 887          888         1       1    1  19.0      0      0    112053
# 889          890         1       1    0  26.0      0      0    111369
#
#         Fare        Cabin Embarked
# 1    71.2833          C85        C
# 3    53.1000         C123        S
# ...

# %%
df= df.drop(columns=['Ticket'])

# %%
df
# Out:
#      PassengerId  Survived  Pclass  Sex   Age  SibSp  Parch     Fare  \
# 1              2         1       1    1  38.0      1      0  71.2833
# 3              4         1       1    1  35.0      1      0  53.1000
# 6              7         0       1    0  54.0      0      0  51.8625
# 10            11         1       3    1   4.0      1      1  16.7000
# 11            12         1       1    1  58.0      0      0  26.5500
# ..           ...       ...     ...  ...   ...    ...    ...      ...
# 871          872         1       1    1  47.0      1      1  52.5542
# 872          873         0       1    0  33.0      0      0   5.0000
# 879          880         1       1    1  56.0      0      1  83.1583
# 887          888         1       1    1  19.0      0      0  30.0000
# 889          890         1       1    0  26.0      0      0  30.0000
#
#            Cabin Embarked
# 1            C85        C
# 3           C123        S
# 6            E46        S
# 10            G6        S
# ...

# %%
df= df.drop(columns=['Cabin'])

# %%
df
# Out:
#      PassengerId  Survived  Pclass  Sex   Age  SibSp  Parch     Fare Embarked
# 1              2         1       1    1  38.0      1      0  71.2833        C
# 3              4         1       1    1  35.0      1      0  53.1000        S
# 6              7         0       1    0  54.0      0      0  51.8625        S
# 10            11         1       3    1   4.0      1      1  16.7000        S
# 11            12         1       1    1  58.0      0      0  26.5500        S
# ..           ...       ...     ...  ...   ...    ...    ...      ...      ...
# 871          872         1       1    1  47.0      1      1  52.5542        S
# 872          873         0       1    0  33.0      0      0   5.0000        S
# 879          880         1       1    1  56.0      0      1  83.1583        C
# 887          888         1       1    1  19.0      0      0  30.0000        S
# 889          890         1       1    0  26.0      0      0  30.0000        C
#
# [183 rows x 9 columns]

# %%
x=df.drop("Embarked", axis = 1)
y=df["Embarked"]

# %%
x
# Out:
#      PassengerId  Survived  Pclass  Sex   Age  SibSp  Parch     Fare
# 1              2         1       1    1  38.0      1      0  71.2833
# 3              4         1       1    1  35.0      1      0  53.1000
# 6              7         0       1    0  54.0      0      0  51.8625
# 10            11         1       3    1   4.0      1      1  16.7000
# 11            12         1       1    1  58.0      0      0  26.5500
# ..           ...       ...     ...  ...   ...    ...    ...      ...
# 871          872         1       1    1  47.0      1      1  52.5542
# 872          873         0       1    0  33.0      0      0   5.0000
# 879          880         1       1    1  56.0      0      1  83.1583
# 887          888         1       1    1  19.0      0      0  30.0000
# 889          890         1       1    0  26.0      0      0  30.0000
#
# [183 rows x 8 columns]

# %%
y
# Out:
# 1      C
# 3      S
# 6      S
# 10     S
# 11     S
#       ..
# 871    S
# 872    S
# 879    C
# 887    S
# 889    C
# Name: Embarked, Length: 183, dtype: object

# %%
from scipy.stats import zscore
z=np.abs(zscore(x))
z
# Out:
#      PassengerId  Survived    Pclass       Sex       Age     SibSp     Parch  \
# 1       1.840135  0.698430  0.372256  1.039012  0.149065  0.833628  0.631730
# 3       1.832017  0.698430  0.372256  1.039012  0.043230  0.833628  0.631730
# 6       1.819841  1.431782  0.372256  0.962453  1.174636  0.723044  0.631730
# 10      1.803606  0.698430  3.520480  1.039012  2.030273  0.833628  0.697081
# 11      1.799547  0.698430  0.372256  1.039012  1.431029  0.723044  0.631730
# ..           ...       ...       ...       ...       ...       ...       ...
# 871     1.691045  0.698430  0.372256  1.039012  0.725949  0.833628  0.697081
# 872     1.695104  1.431782  0.372256  0.962453  0.171426  0.723044  0.631730
# 879     1.723516  0.698430  0.372256  1.039012  1.302832  0.723044  0.697081
# 887     1.755986  0.698430  0.372256  1.039012  1.068801  0.723044  0.631730
# 889     1.764104  0.698430  0.372256  0.962453  0.620113  0.723044  0.631730
#
#          Fare
# 1    0.097180
# ...

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([  3,   7,  12,  13,  34,  42,  71,  80,  82,  86, 137, 142, 148,
#        153, 158, 172], dtype=int64), array([2, 5, 2, 5, 2, 2, 5, 2, 2, 6, 7, 2, 2, 7, 2, 2], dtype=int64))

# %%
df_new=x[(z<3).all(axis=1)]
df_new
# Out:
#      PassengerId  Survived  Pclass  Sex   Age  SibSp  Parch     Fare
# 1              2         1       1    1  38.0      1      0  71.2833
# 3              4         1       1    1  35.0      1      0  53.1000
# 6              7         0       1    0  54.0      0      0  51.8625
# 11            12         1       1    1  58.0      0      0  26.5500
# 21            22         1       2    0  34.0      0      0  13.0000
# ..           ...       ...     ...  ...   ...    ...    ...      ...
# 871          872         1       1    1  47.0      1      1  52.5542
# 872          873         0       1    0  33.0      0      0   5.0000
# 879          880         1       1    1  56.0      0      1  83.1583
# 887          888         1       1    1  19.0      0      0  30.0000
# 889          890         1       1    0  26.0      0      0  30.0000
#
# [167 rows x 8 columns]

# %%
df=df_new

# %%
df
# Out:
#      PassengerId  Survived  Pclass  Sex   Age  SibSp  Parch     Fare
# 1              2         1       1    1  38.0      1      0  71.2833
# 3              4         1       1    1  35.0      1      0  53.1000
# 6              7         0       1    0  54.0      0      0  51.8625
# 11            12         1       1    1  58.0      0      0  26.5500
# 21            22         1       2    0  34.0      0      0  13.0000
# ..           ...       ...     ...  ...   ...    ...    ...      ...
# 871          872         1       1    1  47.0      1      1  52.5542
# 872          873         0       1    0  33.0      0      0   5.0000
# 879          880         1       1    1  56.0      0      1  83.1583
# 887          888         1       1    1  19.0      0      0  30.0000
# 889          890         1       1    0  26.0      0      0  30.0000
#
# [167 rows x 8 columns]

# %%
df.skew()
# Out:
# PassengerId   -0.042525
# Survived      -0.791895
# Pclass         2.895219
# Sex            0.060451
# Age           -0.027528
# SibSp          0.857282
# Parch          1.386356
# Fare           1.517475
# dtype: float64

# %% [markdown]
# Observation :- The data for skewness must fall under -0.5 to +0.5 if not the data is having skewness and will have to remove the skewness with the help of 'boxcox' library

# %%
df['Pclass']=np.cbrt(df['Pclass'])

# %%
df['Parch']=np.cbrt(df['Parch'])

# %%
df['Fare']=np.cbrt(df['Fare'])

# %%
df.skew()
# Out:
# PassengerId   -0.042525
# Survived      -0.791895
# Pclass         2.895219
# Sex            0.060451
# Age           -0.027528
# SibSp          0.857282
# Parch          0.946597
# Fare          -0.247882
# dtype: float64

# %%
df.corr()
# Out:
#              PassengerId  Survived    Pclass       Sex       Age     SibSp  \
# PassengerId     1.000000  0.135926 -0.149746  0.066200 -0.008382  0.030687
# Survived        0.135926  1.000000  0.079212  0.558761 -0.284785  0.140729
# Pclass         -0.149746  0.079212  1.000000  0.072266 -0.232750 -0.020685
# Sex             0.066200  0.558761  0.072266  1.000000 -0.175466  0.076348
# Age            -0.008382 -0.284785 -0.232750 -0.175466  1.000000 -0.154514
# SibSp           0.030687  0.140729 -0.020685  0.076348 -0.154514  1.000000
# Parch          -0.004441  0.054099  0.013413  0.075772 -0.270266  0.143099
# Fare            0.000290  0.181958 -0.403989  0.279354 -0.159988  0.317298
#
#                 Parch      Fare
# PassengerId -0.004441  0.000290
# Survived     0.054099  0.181958
# Pclass       0.013413 -0.403989
# Sex          0.075772  0.279354
# Age         -0.270266 -0.159988
# SibSp        0.143099  0.317298
# Parch        1.000000  0.395706
# ...

# %%
sns.pairplot(df)

# %%
x
# Out:
#      PassengerId  Survived  Pclass  Sex   Age  SibSp  Parch     Fare
# 1              2         1       1    1  38.0      1      0  71.2833
# 3              4         1       1    1  35.0      1      0  53.1000
# 6              7         0       1    0  54.0      0      0  51.8625
# 10            11         1       3    1   4.0      1      1  16.7000
# 11            12         1       1    1  58.0      0      0  26.5500
# ..           ...       ...     ...  ...   ...    ...    ...      ...
# 871          872         1       1    1  47.0      1      1  52.5542
# 872          873         0       1    0  33.0      0      0   5.0000
# 879          880         1       1    1  56.0      0      1  83.1583
# 887          888         1       1    1  19.0      0      0  30.0000
# 889          890         1       1    0  26.0      0      0  30.0000
#
# [183 rows x 8 columns]

# %%
y
# Out:
# 1      C
# 3      S
# 6      S
# 10     S
# 11     S
#       ..
# 871    S
# 872    S
# 879    C
# 887    S
# 889    C
# Name: Embarked, Length: 183, dtype: object

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x=pd.DataFrame(scaler.fit_transform(x),columns=x.columns)
x
# Out:
#      PassengerId  Survived    Pclass       Sex       Age     SibSp     Parch  \
# 0      -1.840135  0.698430 -0.372256  1.039012  0.149065  0.833628 -0.631730
# 1      -1.832017  0.698430 -0.372256  1.039012 -0.043230  0.833628 -0.631730
# 2      -1.819841 -1.431782 -0.372256 -0.962453  1.174636 -0.723044 -0.631730
# 3      -1.803606  0.698430  3.520480  1.039012 -2.030273  0.833628  0.697081
# 4      -1.799547  0.698430 -0.372256  1.039012  1.431029 -0.723044 -0.631730
# ..           ...       ...       ...       ...       ...       ...       ...
# 178     1.691045  0.698430 -0.372256  1.039012  0.725949  0.833628  0.697081
# 179     1.695104 -1.431782 -0.372256 -0.962453 -0.171426 -0.723044 -0.631730
# 180     1.723516  0.698430 -0.372256  1.039012  1.302832 -0.723044  0.697081
# 181     1.755986  0.698430 -0.372256  1.039012 -1.068801 -0.723044 -0.631730
# 182     1.764104  0.698430 -0.372256 -0.962453 -0.620113 -0.723044 -0.631730
#
#          Fare
# 0   -0.097180
# ...

# %% [markdown]
# Checking VIF

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=pd.DataFrame()
vif["VIF values"]=[variance_inflation_factor(x.values,i)
                  for i in range(len(x.columns))]
vif["Features"]=x.columns
vif
# Out:
#    VIF values     Features
# 0    1.047190  PassengerId
# 1    1.528894     Survived
# 2    1.318797       Pclass
# 3    1.426726          Sex
# 4    1.315396          Age
# 5    1.153160        SibSp
# 6    1.321211        Parch
# 7    1.433592         Fare

# %% [markdown]
# By checking VIF values we can find the features causing multicollineraity problem.We can find that none of the columns have High VIF hence we will not drop any columns

# %%
y.value_counts()
# Out:
# S    116
# C     65
# Q      2
# Name: Embarked, dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier 
from sklearn.metrics import accuracy_score
maxAccu = 0 
maxRS = 0
for i in range(1,200):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=i)
    RFR =RandomForestClassifier()
    RFR.fit(x_train,y_train)
    pred=RFR.predict(x_test)
    acc=accuracy_score(y_test,pred)
    if acc>maxAccu:
        maxAccu=acc
        maxRS=i
        
print("Best accuracy is",maxAccu,"at random_state",maxRS)
# Out:
# Best accuracy is 0.7454545454545455 at random_state 110

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=maxRS)

# %%
from sklearn.ensemble import RandomForestClassifier,ExtraTreesClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import GradientBoostingClassifier,AdaBoostClassifier,BaggingClassifier
from sklearn.metrics import classification_report,confusion_matrix,roc_curve,accuracy_score
from sklearn.model_selection import cross_val_score

# %%
RFC= RandomForestClassifier()
RFC.fit(x_train,y_train)
predRFC = RFC.predict(x_test)
print(accuracy_score(y_test,predRFC))
print(confusion_matrix(y_test,predRFC))
print(classification_report(y_test,predRFC))
# Out:
# 0.6909090909090909
# [[10  6]
#  [11 28]]
#               precision    recall  f1-score   support
#
#            C       0.48      0.62      0.54        16
#            S       0.82      0.72      0.77        39
#
#     accuracy                           0.69        55
#    macro avg       0.65      0.67      0.65        55
# weighted avg       0.72      0.69      0.70        55

# %%
LR= LogisticRegression()
LR.fit(x_train,y_train)
predLR=LR.predict(x_test)
print(accuracy_score(y_test,predLR))
print(confusion_matrix(y_test,predLR))
print(classification_report(y_test,predLR))
# Out:
# 0.6545454545454545
# [[ 3 13]
#  [ 6 33]]
#               precision    recall  f1-score   support
#
#            C       0.33      0.19      0.24        16
#            S       0.72      0.85      0.78        39
#
#     accuracy                           0.65        55
#    macro avg       0.53      0.52      0.51        55
# weighted avg       0.61      0.65      0.62        55

# %%
svc= SVC()
svc.fit(x_train,y_train)
predsvc=svc.predict(x_test)
print(accuracy_score(y_test,predsvc))
print(confusion_matrix(y_test,predsvc))
print(classification_report(y_test,predsvc))
# Out:
# 0.7272727272727273
# [[ 4 12]
#  [ 3 36]]
#               precision    recall  f1-score   support
#
#            C       0.57      0.25      0.35        16
#            S       0.75      0.92      0.83        39
#
#     accuracy                           0.73        55
#    macro avg       0.66      0.59      0.59        55
# weighted avg       0.70      0.73      0.69        55

# %%
GB= GradientBoostingClassifier()
GB.fit(x_train,y_train)
predGB=GB.predict(x_test)
print(accuracy_score(y_test,predGB))
print(confusion_matrix(y_test,predGB))
print(classification_report(y_test,predGB))
# Out:
# 0.6909090909090909
# [[10  6]
#  [11 28]]
#               precision    recall  f1-score   support
#
#            C       0.48      0.62      0.54        16
#            S       0.82      0.72      0.77        39
#
#     accuracy                           0.69        55
#    macro avg       0.65      0.67      0.65        55
# weighted avg       0.72      0.69      0.70        55

# %%
from sklearn.model_selection import cross_val_score

# %%
score=cross_val_score(RFC,x,y)
print(score)
print(score.mean())
print("The difference between accuracy score and cross validation score is - ",accuracy_score(y_test,predRFC)- score.mean())
# Out:
# [0.64864865 0.64864865 0.64864865 0.61111111 0.63888889]
# 0.6391891891891892
# The difference between accuracy score and cross validation score is -  0.051719901719901706

# %%
score=cross_val_score(LR,x,y)
print(score)
print(score.mean())
print("The difference between accuracy score and cross validation score is - ",accuracy_score(y_test,predLR)- score.mean())
# Out:
# [0.64864865 0.62162162 0.59459459 0.55555556 0.69444444]
# 0.6229729729729729
# The difference between accuracy score and cross validation score is -  0.0315724815724816

# %%
score=cross_val_score(svc,x,y)
print(score)
print(score.mean())
print("The difference between accuracy score and cross validation score is - ",accuracy_score(y_test,predRFC)- score.mean())
# Out:
# [0.72972973 0.62162162 0.59459459 0.55555556 0.61111111]
# 0.6225225225225226
# The difference between accuracy score and cross validation score is -  0.06838656838656831

# %%
score=cross_val_score(GB,x,y)
print(score)
print(score.mean())
print("The difference between accuracy score and cross validation score is - ",accuracy_score(y_test,predRFC)- score.mean())
# Out:
# [0.35135135 0.56756757 0.7027027  0.63888889 0.61111111]
# 0.5743243243243243
# The difference between accuracy score and cross validation score is -  0.11658476658476657
