# %% [markdown]
# Importing all the important libraries

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('https://raw.githubusercontent.com/dsrscientist/Data-Science-ML-Capstone-Projects/master/baseball.csv')
df
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# ...

# %% [markdown]
# Observation- The output data is in numerical format, hence we will Linear regression.

# %%
df.shape
# Out:
# (30, 17)

# %% [markdown]
# Number of rows-30 Number of columns-17

# %%
df.ndim
# Out:
# 2

# %% [markdown]
# The data is 2-Dimensional data

# %%
df.columns
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %% [markdown]
# This are all 17 rows in which W is the output and rest are the parameters based on baseball game

# %%
df.min()
# Out:
# W        63.00
# R       573.00
# AB     5385.00
# H      1324.00
# 2B      236.00
# 3B       13.00
# HR      100.00
# BB      375.00
# SO      973.00
# SB       44.00
# RA      525.00
# ER      478.00
# ERA       2.94
# CG        0.00
# SHO       4.00
# SV       28.00
# E        75.00
# dtype: float64

# %% [markdown]
# the minimum number of Wins is '63'

# %%
df.max()
# Out:
# W       100.00
# R       891.00
# AB     5649.00
# H      1515.00
# 2B      308.00
# 3B       49.00
# HR      232.00
# BB      570.00
# SO     1518.00
# SB      134.00
# RA      844.00
# ER      799.00
# ERA       5.04
# CG       11.00
# SHO      21.00
# SV       62.00
# E       126.00
# dtype: float64

# %% [markdown]
# the maximum number of Wins is '100'

# %%
df.W.value_counts()
# Out:
# 68     3
# 81     2
# 76     2
# 74     2
# 83     2
# 98     1
# 84     1
# 92     1
# 63     1
# 67     1
# 71     1
# 90     1
# 64     1
# 97     1
# 95     1
# 100    1
# 85     1
# 86     1
# 88     1
# 78     1
# 80     1
# 87     1
# 93     1
# 79     1
# Name: W, dtype: int64

# %%
print(df['W'].value_counts())
sns.countplot(df['W'],palette="cool")
# Out:
# 68     3
# 81     2
# 76     2
# 74     2
# 83     2
# 98     1
# 84     1
# 92     1
# 63     1
# 67     1
# 71     1
# 90     1
# 64     1
# 97     1
# 95     1
# 100    1
# 85     1
# 86     1
# 88     1
# 78     1
# 80     1
# 87     1
# 93     1
# 79     1
# Name: W, dtype: int64
# <AxesSubplot:xlabel='W', ylabel='count'>

# %%
df.W.unique()
# Out:
# array([ 95,  83,  81,  76,  74,  93,  87,  80,  78,  88,  86,  85,  68,
#        100,  98,  97,  64,  90,  71,  67,  63,  92,  84,  79], dtype=int64)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %%
df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# ...

# %% [markdown]
# Observation : - 1)Standard deviation of "R","AB","H","HR","BB","SO","RA","IS" is bit high hence the data is spreaded and there is possibilities of outliers.
#
# 2)mean is almost equal to median so there is very little or no skewness in data in columns.
#
# 3)There is a bit difference in the 75% and max_value in "SB","RA","HR" hence there is high possibility of outliers in the dataset.

# %%
df.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %% [markdown]
# Observation- As we can see that there are no null values in the given dataset, still checking it in the heatmap.

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# Observation- As seen in isnull() we cannot find any null value in the given dataset

# %%
dfcor=df.corr()
dfcor
# Out:
#             W         R        AB         H        2B        3B        HR  \
# W    1.000000  0.430751 -0.087947  0.037612  0.427797 -0.251118  0.307407
# R    0.430751  1.000000  0.319464  0.482856  0.560084 -0.070072  0.671283
# AB  -0.087947  0.319464  1.000000  0.739122  0.453370  0.435422 -0.066983
# H    0.037612  0.482856  0.739122  1.000000  0.566847  0.478694 -0.090855
# 2B   0.427797  0.560084  0.453370  0.566847  1.000000  0.220490  0.056292
# 3B  -0.251118 -0.070072  0.435422  0.478694  0.220490  1.000000 -0.430915
# HR   0.307407  0.671283 -0.066983 -0.090855  0.056292 -0.430915  1.000000
# BB   0.484342  0.402452 -0.136414 -0.118281  0.302700 -0.454949  0.425691
# SO   0.111850 -0.054726 -0.106022 -0.398830 -0.150752 -0.141196  0.359923
# SB  -0.157234  0.081367  0.372618  0.413444  0.195027  0.457437 -0.136567
# RA  -0.812952 -0.041623  0.316010  0.224324 -0.218160  0.314125 -0.103903
# ER  -0.809435 -0.041245  0.309686  0.252489 -0.235531  0.340225 -0.085922
# ...

# %% [markdown]
# To understand the relationship between the 2 variables lets put this correlation data in heatmap

# %%
sns.heatmap(dfcor)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Observation- From the heatmap we can see that "RA","ER","ERA" are highly correleated to each other, If we see "W" it is correleated with "SV" i.e Save and "SHO" i.e Shutout, The more number of "SV" and "SHO" the more chances of Win

# %% [markdown]
# Checking the correlation with the help of graphical representation

# %%
plt.figure(figsize=(20,15))
sns.heatmap(dfcor,cmap='Blues',fmt=".1g",annot=True)
plt.yticks(rotation=0);
 
plt.show()

# %%
plt.figure(figsize=(22,7))
df.corr()['W'].sort_values(ascending = False).drop(['W']).plot(kind='bar',color="m")
plt.xlabel('Feature',fontsize =15)
plt.ylabel('Target',fontsize=15)
plt.title("Correlation between W and other baseball parameters using barplot",fontsize=20)
plt.show()

# %% [markdown]
# Observation - As we can see "SV" is Highly correleated with "W" and "ERA" is negatively correleated

# %%
sns.pairplot(df,hue="W", palette= "Dark2")
plt.show()

# %%
df.plot(kind='box',subplots=True,layout =(4,5),figsize=(12,8))
# Out:
# W         AxesSubplot(0.125,0.712609;0.133621x0.167391)
# R      AxesSubplot(0.285345,0.712609;0.133621x0.167391)
# AB      AxesSubplot(0.44569,0.712609;0.133621x0.167391)
# H      AxesSubplot(0.606034,0.712609;0.133621x0.167391)
# 2B     AxesSubplot(0.766379,0.712609;0.133621x0.167391)
# 3B        AxesSubplot(0.125,0.511739;0.133621x0.167391)
# HR     AxesSubplot(0.285345,0.511739;0.133621x0.167391)
# BB      AxesSubplot(0.44569,0.511739;0.133621x0.167391)
# SO     AxesSubplot(0.606034,0.511739;0.133621x0.167391)
# SB     AxesSubplot(0.766379,0.511739;0.133621x0.167391)
# RA         AxesSubplot(0.125,0.31087;0.133621x0.167391)
# ER      AxesSubplot(0.285345,0.31087;0.133621x0.167391)
# ERA      AxesSubplot(0.44569,0.31087;0.133621x0.167391)
# CG      AxesSubplot(0.606034,0.31087;0.133621x0.167391)
# SHO     AxesSubplot(0.766379,0.31087;0.133621x0.167391)
# SV            AxesSubplot(0.125,0.11;0.133621x0.167391)
# E          AxesSubplot(0.285345,0.11;0.133621x0.167391)
# ...

# %% [markdown]
# Observation- We can see there are some outliers in "R","ERA","SHO","SV","E", We need to remove all the outliers from the given dataset

# %%
from scipy.stats import zscore
out_features=df[['R','ERA','SHO','SV','E']]
z=np.abs(zscore(out_features))
z
# Out:
#            R       ERA       SHO        SV         E
# 0   0.619078  0.506955  0.814629  1.671607  0.461470
# 1   0.134432  0.254598  0.172800  0.249879  0.607197
# 2   0.332906  0.641347  0.320914  0.654856  1.117242
# 3   1.146419  0.053010  0.567771  0.784104  0.485758
# 4   0.013270  1.531318  0.172800  1.042600  0.607197
# 5   3.509647  0.350165  0.320914  1.171848  0.461470
# 6   1.311430  0.165003  1.802057  0.637623  0.097152
# 7   0.428681  0.209800  0.320914  0.008617  1.262970
# 8   0.765626  0.484557  0.172800  2.188598  0.048576
# 9   1.034489  0.792164  0.320914  0.396360  0.194303
# 10  1.086415  0.635374  0.567771  0.249879  1.797303
# 11  0.705622  0.865333  0.419657  0.525608  0.680061
# 12  0.471376  0.036584  0.172800  0.379127  0.097152
# 13  0.557920  0.456185  0.172800  0.249879  0.024288
# 14  0.099814  0.411388  0.913371  1.947335  2.307348
# 15  0.713699  2.276445  0.913371  2.447094  0.121439
# 16  0.151740  1.671683  0.419657  1.413111  2.015894
# ...

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([5], dtype=int64), array([0], dtype=int64))

# %%
df_new=df[(z<3).all(axis=1)]
df_new
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# 11   86  729  5459  1363  278  26  230  486  1392  121  618  572  3.57   5
# ...

# %%
df_new.shape
# Out:
# (29, 17)

# %%
df=df_new
df
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# 11   86  729  5459  1363  278  26  230  486  1392  121  618  572  3.57   5
# ...

# %%
df.shape
# Out:
# (29, 17)

# %% [markdown]
# Observation- Outliers have been removed successfully, rows count come down to 29

# %% [markdown]
# Now, checking the skewness

# %%
sns.distplot(df['R'])
# Out:
# <AxesSubplot:xlabel='R', ylabel='Density'>

# %%
sns.distplot(df['AB'])
# Out:
# <AxesSubplot:xlabel='AB', ylabel='Density'>

# %%
sns.distplot(df['H'])
# Out:
# <AxesSubplot:xlabel='H', ylabel='Density'>

# %%
sns.distplot(df['2B'])
# Out:
# <AxesSubplot:xlabel='2B', ylabel='Density'>

# %%
sns.distplot(df['3B'])
# Out:
# <AxesSubplot:xlabel='3B', ylabel='Density'>

# %%
sns.distplot(df['HR'])
# Out:
# <AxesSubplot:xlabel='HR', ylabel='Density'>

# %%
sns.distplot(df['BB'])
# Out:
# <AxesSubplot:xlabel='BB', ylabel='Density'>

# %%
sns.distplot(df['SO'])
# Out:
# <AxesSubplot:xlabel='SO', ylabel='Density'>

# %%
sns.distplot(df['SB'])
# Out:
# <AxesSubplot:xlabel='SB', ylabel='Density'>

# %%
sns.distplot(df['RA'])
# Out:
# <AxesSubplot:xlabel='RA', ylabel='Density'>

# %%
sns.distplot(df['ER'])
# Out:
# <AxesSubplot:xlabel='ER', ylabel='Density'>

# %%
sns.distplot(df['ERA'])
# Out:
# <AxesSubplot:xlabel='ERA', ylabel='Density'>

# %%
sns.distplot(df['CG'])
# Out:
# <AxesSubplot:xlabel='CG', ylabel='Density'>

# %%
sns.distplot(df['SHO'])
# Out:
# <AxesSubplot:xlabel='SHO', ylabel='Density'>

# %%
sns.distplot(df['SV'])
# Out:
# <AxesSubplot:xlabel='SV', ylabel='Density'>

# %%
sns.distplot(df['E'])
# Out:
# <AxesSubplot:xlabel='E', ylabel='Density'>

# %% [markdown]
# Observation- With the help of distplot and pair plot we can see that there is a bit skewness in the given dataset, the skewness is too low that it can be ignored still removing skewness for better output

# %% [markdown]
# Checking the skewness

# %%
df.skew()
# Out:
# W      0.119013
# R     -0.215364
# AB     0.169573
# H      0.783772
# 2B    -0.335304
# 3B     0.090124
# HR     0.450862
# BB     0.151193
# SO    -0.233815
# SB     0.494966
# RA     0.018155
# ER     0.018461
# ERA    0.016693
# CG     0.854980
# SHO    0.526943
# SV     0.627480
# E      0.840271
# dtype: float64

# %% [markdown]
# Observation - The data of skewness must fall between -0.5 to +0.5. If not, the data is having the skewness. here we can see that there is less or no skewness in the given dataset, asmentioned above, hence ignoring this parameter of EDA

# %% [markdown]
# Again checking the correlation in the given dataset

# %%
df.corr()
# Out:
#             W         R        AB         H        2B        3B        HR  \
# W    1.000000  0.390451 -0.085780 -0.018360  0.384886 -0.206737  0.245697
# R    0.390451  1.000000  0.438022  0.433525  0.469293  0.134204  0.586894
# AB  -0.085780  0.438022  1.000000  0.769159  0.490752  0.445604 -0.064653
# H   -0.018360  0.433525  0.769159  1.000000  0.528016  0.582024 -0.218711
# 2B   0.384886  0.469293  0.490752  0.528016  1.000000  0.342419 -0.098695
# 3B  -0.206737  0.134204  0.445604  0.582024  0.342419  1.000000 -0.369299
# HR   0.245697  0.586894 -0.064653 -0.218711 -0.098695 -0.369299  1.000000
# BB   0.447513  0.258450 -0.137850 -0.222271  0.211243 -0.404852  0.336814
# SO   0.156469  0.081158 -0.111243 -0.371861 -0.096772 -0.196586  0.479914
# SB  -0.169503  0.075323  0.373674  0.417877  0.194308  0.483818 -0.166072
# RA  -0.823176 -0.013858  0.315499  0.244606 -0.215196  0.312750 -0.092586
# ER  -0.815308  0.007727  0.309146  0.280571 -0.224993  0.333731 -0.062094
# ...

# %% [markdown]
# Observation- We will not drop any of the column, as droping the column will lead to uncertain output.

# %%
x=df.drop("W", axis = 1)
y=df["W"]

# %%
x
# Out:
#       R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0   724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1   696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2   669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3   622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4   689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
# 6   764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3    4
# 7   713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0   10
# 8   644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1   12
# 9   748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3   10
# 10  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5    9
# 11  729  5459  1363  278  26  230  486  1392  121  618  572  3.57   5   13
# ...

# %%
y
# Out:
# 0      95
# 1      83
# 2      81
# 3      76
# 4      74
# 6      87
# 7      81
# 8      80
# 9      78
# 10     88
# 11     86
# 12     85
# 13     76
# 14     68
# 15    100
# 16     98
# 17     97
# 18     68
# 19     64
# 20     90
# 21     83
# 22     71
# 23     67
# 24     63
# 25     92
# 26     84
# 27     79
# 28     74
# 29     68
# Name: W, dtype: int64

# %% [markdown]
# Observation- We have divided the data in x & y so that it can be well fitted in the machine learning model

# %% [markdown]
# Feature Scaling the data using standard Scaler

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x=pd.DataFrame(scaler.fit_transform(x),columns=x.columns)
x
# Out:
#            R        AB         H        2B        3B        HR        BB  \
# 0   0.959398  0.830084  1.738306  1.556538  1.010845 -0.765863 -1.536359
# 1   0.331147 -0.702831 -0.938698  0.201171  1.208917 -0.181389 -0.495021
# 2  -0.274666 -1.100253 -0.106656  1.733325 -0.276617 -0.697101  1.252941
# 3  -1.329231  0.233951 -0.359886 -0.800621 -0.474688 -0.869006 -1.145857
# 4   0.174084  1.255894  2.063888  0.908319  1.704094 -0.353293 -0.197495
# 5   1.856900  0.716535 -0.070480 -0.093474 -1.266972  1.743939  1.643442
# 6   0.712585 -0.447345 -0.558853 -1.625627 -1.167936  1.915843 -0.885522
# 7  -0.835605 -0.447345 -0.323710  0.260100  0.020490  0.196801 -0.550807
# 8   1.497899  1.752672  1.702131  1.202964  0.119526 -0.009484  0.230197
# 9   1.565212 -0.078310  0.327453  0.319029  0.020490  0.368705  0.695081
# 10  1.071586 -0.816380 -0.685468  0.260100 -0.573723  2.362794  0.378960
# 11 -0.454167 -1.412514 -1.264279 -1.802414 -1.068901  0.506228 -0.569402
# ...

# %% [markdown]
# To overcome the issue of biasness we have scaled the data

# %% [markdown]
# Checking the Variance Inflation factor (VIF)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=pd.DataFrame()
vif["VIF values"]=[variance_inflation_factor(x.values,i)
                  for i in range(len(x.columns))]
vif["Features"]=x.columns
vif
# Out:
#      VIF values Features
# 0      7.229564        R
# 1     18.333377       AB
# 2     10.558458        H
# 3      3.743423       2B
# 4      3.278636       3B
# 5      8.426403       HR
# 6      3.431971       BB
# 7      2.720640       SO
# 8      2.110804       SB
# 9    197.315706       RA
# 10  1825.871631       ER
# 11  1438.816208      ERA
# 12     3.074115       CG
# 13     3.673885      SHO
# 14     6.236487       SV
# 15     2.180914        E

# %% [markdown]
# By checking VIF values we can find the features causing multicollineraity problem.We can find that "ER","RA","ERA" is having the highest VIF, we will drop this column first respectively and check the vif again

# %%
x.drop("ER", axis=1, inplace= True)

# %% [markdown]
# Observation :- Checking VIF value to confirm whether the multicollinearity still exist or not

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=pd.DataFrame()
vif["VIF values"]=[variance_inflation_factor(x.values,i)
                  for i in range(len(x.columns))]
vif["Features"]=x.columns
vif
# Out:
#     VIF values Features
# 0     6.789990        R
# 1     7.689961       AB
# 2     9.703669        H
# 3     3.423326       2B
# 4     3.268301       3B
# 5     7.683683       HR
# 6     3.430050       BB
# 7     2.713114       SO
# 8     1.907595       SB
# 9   144.425392       RA
# 10  139.967064      ERA
# 11    2.649316       CG
# 12    3.498198      SHO
# 13    3.174949       SV
# 14    2.092189        E

# %% [markdown]
# There is again a high Vif value in "RA", "ERA", dropping "RA" as this column is having the highest vif value and again checking the vif

# %%
x.drop("RA", axis=1, inplace= True)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=pd.DataFrame()
vif["VIF values"]=[variance_inflation_factor(x.values,i)
                  for i in range(len(x.columns))]
vif["Features"]=x.columns
vif
# Out:
#     VIF values Features
# 0     6.787762        R
# 1     4.981743       AB
# 2     8.569581        H
# 3     3.416116       2B
# 4     3.239565       3B
# 5     6.590925       HR
# 6     3.081560       BB
# 7     2.106522       SO
# 8     1.842528       SB
# 9     4.931066      ERA
# 10    2.649063       CG
# 11    3.231029      SHO
# 12    3.075865       SV
# 13    2.039641        E

# %% [markdown]
#     Observation- Now, everything seems to be in control, the issue of multi-collinearity is removed successfully. We cannot drop more columns as we should have columns to analyze the given dataset

# %%
y.value_counts()
# Out:
# 68     3
# 81     2
# 76     2
# 74     2
# 83     2
# 97     1
# 84     1
# 92     1
# 63     1
# 67     1
# 71     1
# 90     1
# 64     1
# 95     1
# 98     1
# 100    1
# 85     1
# 86     1
# 88     1
# 78     1
# 80     1
# 87     1
# 79     1
# Name: W, dtype: int64

# %%
sns.lmplot(x='R', y= 'W' , data=df,)

# %%
sns.lmplot(x='AB', y= 'W' , data=df,)

# %%
sns.lmplot(x='H', y= 'W' , data=df,)

# %%
sns.lmplot(x='2B', y= 'W' , data=df,)

# %%
sns.lmplot(x='3B', y= 'W' , data=df_new,)

# %%
sns.lmplot(x='HR', y= 'W' , data=df_new,)

# %%
sns.lmplot(x='BB', y= 'W' , data=df_new,)

# %%
sns.lmplot(x='SO', y= 'W' , data=df_new,)

# %%
sns.lmplot(x='SB', y= 'W' , data=df_new,)

# %%
sns.lmplot(x='RA', y= 'W' , data=df_new,)

# %%
sns.lmplot(x='ER', y= 'W' , data=df_new,)

# %%
sns.lmplot(x='ERA', y= 'W' , data=df_new,)

# %%
sns.lmplot(x='CG', y= 'W' , data=df_new,)

# %%
sns.lmplot(x='SHO', y= 'W' , data=df_new,)

# %%
sns.lmplot(x='SV', y= 'W' , data=df_new,)

# %%
sns.lmplot(x='E', y= 'W' , data=df_new,)

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.linear_model import LinearRegression

# %%
maxAccu=0
maxRS=0
for i in range(1,200):
    x_train,x_test,y_train,y_test = train_test_split(x,y,test_size= 0.33,random_state=i)
    lr=LinearRegression()
    lr.fit(x_train,y_train)
    pred=lr.predict(x_test)
    acc=r2_score(y_test,pred)
    if acc>maxAccu:
        maxAccu=acc
        maxRS=i
print("maximum r2 score is ",maxAccu, "on Random_state",maxRS)
# Out:
# maximum r2 score is  0.8602442317260812 on Random_state 7

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size =0.30,random_state=maxRS)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import Lasso,Ridge

# %%
LR=LinearRegression()
LR.fit(x_train,y_train)
pred_LR=LR.predict(x_test)
pred_train=LR.predict(x_train)
print('R2_score:', r2_score(y_test,pred_LR))
print('R2_score on training data:', r2_score(y_train,pred_train)*100)
print('Mean Absolute Error :-', mean_absolute_error(y_test,pred_LR))
print('Mean_Squared_Error :- ', mean_squared_error (y_test,pred_LR))
print('Root Mean Square Error:-', np.sqrt(mean_squared_error(y_test,pred_LR)))
# Out:
# R2_score: 0.845745629933156
# R2_score on training data: 94.33718329405274
# Mean Absolute Error :- 3.6538172199643264
# Mean_Squared_Error :-  16.659471967219147
# Root Mean Square Error:- 4.081601642397154

# %% [markdown]
# Observation- The score is 84%

# %%
plt.figure(figsize=(10,6))
plt.scatter(x=pred_LR,y=y_test,color='r')
plt.plot(pred_LR,pred_LR,color='b')
plt.xlabel('Actual',fontsize=14)
plt.ylabel('Predicted',fontsize=14)
plt.title("Linear Regression",fontsize=18)
plt.show()

# %%
RFR=RandomForestRegressor()
RFR.fit(x_train,y_train)
pred_RFR=RFR.predict(x_test)
pred_train=RFR.predict(x_train)
print('R2_score:', r2_score(y_test,pred_RFR))
print('R2_score on training data:', r2_score(y_train,pred_train)*100)
print('Mean Absolute Error :-', mean_absolute_error(y_test,pred_RFR))
print('Mean_Squared_Error :- ', mean_squared_error (y_test,pred_RFR))
print('Root Mean Square Error:-', np.sqrt(mean_squared_error(y_test,pred_RFR)))
# Out:
# R2_score: 0.43631399176954777
# R2_score on training data: 93.20105171772293
# Mean Absolute Error :- 7.353333333333331
# Mean_Squared_Error :-  60.87808888888885
# Root Mean Square Error:- 7.80244121342089

# %% [markdown]
# Observation- The score is 43%

# %%
GBR=GradientBoostingRegressor()
GBR.fit(x_train,y_train)
pred_GBR=GBR.predict(x_test)
pred_train=GBR.predict(x_train)
print('R2_score:', r2_score(y_test,pred_GBR))
print('R2_score on training data:', r2_score(y_train,pred_train)*100)
print('Mean Absolute Error :-', mean_absolute_error(y_test,pred_GBR))
print('Mean_Squared_Error :- ', mean_squared_error (y_test,pred_GBR))
print('Root Mean Square Error:-', np.sqrt(mean_squared_error(y_test,pred_GBR)))
# Out:
# R2_score: 0.4366658237451454
# R2_score on training data: 99.99999501355443
# Mean Absolute Error :- 7.059703257894294
# Mean_Squared_Error :-  60.840091035524296
# Root Mean Square Error:- 7.800005835608348

# %% [markdown]
# Observation- The score is 43%

# %%
lasso=Lasso()
lasso.fit(x_train,y_train)
pred_lasso=lasso.predict(x_test)
pred_train=lasso.predict(x_train)
print('R2_score:', r2_score(y_test,pred_lasso))
print('R2_score on training data:', r2_score(y_train,pred_train)*100)
print('Mean Absolute Error :-', mean_absolute_error(y_test,pred_lasso))
print('Mean_Squared_Error :- ', mean_squared_error (y_test,pred_lasso))
print('Root Mean Square Error:-', np.sqrt(mean_squared_error(y_test,pred_lasso)))
# Out:
# R2_score: 0.7587547158262413
# R2_score on training data: 88.36837525881917
# Mean Absolute Error :- 4.723819799740643
# Mean_Squared_Error :-  26.05449069076593
# Root Mean Square Error:- 5.104359968768458

# %% [markdown]
# Observation- The score is 75%

# %%
rd=Ridge()
rd.fit(x_train,y_train)
pred_rd=rd.predict(x_test)
pred_train=rd.predict(x_train)
print('R2_score:', r2_score(y_test,pred_rd))
print('R2_score on training data:', r2_score(y_train,pred_train)*100)
print('Mean Absolute Error :-', mean_absolute_error(y_test,pred_rd))
print('Mean_Squared_Error :- ', mean_squared_error (y_test,pred_rd))
print('Root Mean Square Error:-', np.sqrt(mean_squared_error(y_test,pred_rd)))
# Out:
# R2_score: 0.8163389695516461
# R2_score on training data: 93.55848139145996
# Mean Absolute Error :- 3.8281299212633026
# Mean_Squared_Error :-  19.835391288422215
# Root Mean Square Error:- 4.453694117069808

# %% [markdown]
# Observation- The score is 81%

# %%
from sklearn.tree import DecisionTreeRegressor
dtr=DecisionTreeRegressor()
dtr.fit(x_train,y_train)
pred_dtr=dtr.predict(x_test)
pred_train=dtr.predict(x_train)
print('R2_score:', r2_score(y_test,pred_dtr))
print('R2_score on training data:', r2_score(y_train,pred_train)*100)
print('Mean Absolute Error :-', mean_absolute_error(y_test,pred_dtr))
print('Mean_Squared_Error :- ', mean_squared_error (y_test,pred_dtr))
print('Root Mean Square Error:-', np.sqrt(mean_squared_error(y_test,pred_dtr)))
# Out:
# R2_score: -0.20576131687242794
# R2_score on training data: 100.0
# Mean Absolute Error :- 9.11111111111111
# Mean_Squared_Error :-  130.22222222222223
# Root Mean Square Error:- 11.41149517908246

# %% [markdown]
# Observation- The score is -20%

# %%
from sklearn.svm import SVR
svr=SVR()
svr.fit(x_train,y_train)
pred_svr=svr.predict(x_test)
pred_train=svr.predict(x_train)
print('R2_score:', r2_score(y_test,pred_svr))
print('R2_score on training data:', r2_score(y_train,pred_train)*100)
print('Mean Absolute Error :-', mean_absolute_error(y_test,pred_svr))
print('Mean_Squared_Error :- ', mean_squared_error (y_test,pred_svr))
print('Root Mean Square Error:-', np.sqrt(mean_squared_error(y_test,pred_svr)))
# Out:
# R2_score: 0.13442826505096006
# R2_score on training data: 17.944276378847025
# Mean Absolute Error :- 8.735961951198497
# Mean_Squared_Error :-  93.48174737449631
# Root Mean Square Error:- 9.668595936044504

# %% [markdown]
# Observation- The score is 13%

# %%
from sklearn.ensemble import ExtraTreesRegressor
etr=ExtraTreesRegressor()
etr.fit(x_train,y_train)
pred_etr=etr.predict(x_test)
pred_train=etr.predict(x_train)
print('R2_score:', r2_score(y_test,pred_etr))
print('R2_score on training data:', r2_score(y_train,pred_train)*100)
print('Mean Absolute Error :-', mean_absolute_error(y_test,pred_etr))
print('Mean_Squared_Error :- ', mean_squared_error (y_test,pred_etr))
print('Root Mean Square Error:-', np.sqrt(mean_squared_error(y_test,pred_etr)))
# Out:
# R2_score: 0.5474653292181071
# R2_score on training data: 100.0
# Mean Absolute Error :- 6.445555555555554
# Mean_Squared_Error :-  48.87374444444444
# Root Mean Square Error:- 6.9909759293280676

# %% [markdown]
# Observation- The score is 54%

# %% [markdown]
# Apart from "Linear Regression model" every model have very less r2 score, Hence we will select the LR model as final model

# %%
from sklearn.model_selection import cross_val_score

# %%
score=cross_val_score(LR,x,y,cv=5,scoring='r2')
print(score)
print(score.mean())
print("Difference between R2 score and cross validation is :- ",(r2_score(y_test,pred_LR)- score.mean())*100)
# Out:
# [ 0.59960667 -1.04852042  0.63023213  0.56003545  0.7367276 ]
# 0.2956162841694411
# Difference between R2 score and cross validation is :-  55.0129345763715

# %%
score1=cross_val_score(RFR,x,y,cv=5,scoring='r2')
print(score1)
print(score1.mean())
print("Difference between R2 score and cross validation is :- ",(r2_score(y_test,pred_RFR)- score.mean())*100)
# Out:
# [ 0.29290239 -4.95198947  0.41736294  0.41288689  0.82572317]
# -0.6006228171060242
# Difference between R2 score and cross validation is :-  14.06977076001067

# %%
score2=cross_val_score(svr,x,y,cv=5,scoring='r2')
print(score2)
print(score2.mean())
print("Difference between R2 score and cross validation is :- ",(r2_score(y_test,pred_svr)- score.mean())*100)
# Out:
# [-0.10238097 -1.21049704 -0.01843886 -0.47226586  0.16186819]
# -0.3283429068070836
# Difference between R2 score and cross validation is :-  -16.118801911848102

# %%
score3=cross_val_score(etr,x,y,cv=5,scoring='r2')
print(score3)
print(score3.mean())
print("Difference between R2 score and cross validation is :- ",(r2_score(y_test,pred_etr)- score.mean())*100)
# Out:
# [ 0.0363192  -4.28846711  0.56596152  0.36230443  0.77105366]
# -0.5105656592904482
# Difference between R2 score and cross validation is :-  25.1849045048666

# %%
score4=cross_val_score(dtr,x,y,cv=5,scoring='r2')
print(score4)
print(score4.mean())
print("Difference between R2 score and cross validation is :- ",(r2_score(y_test,pred_dtr)- score.mean())*100)
# Out:
# [ -1.50909091 -10.47368421   0.23881221   0.86885246  -0.46816038]
# -2.268654165099183
# Difference between R2 score and cross validation is :-  -50.1377601041869

# %%
score5=cross_val_score(GBR,x,y,cv=5,scoring='r2')
print(score5)
print(score5.mean())
print("Difference between R2 score and cross validation is :- ",(r2_score(y_test,pred_GBR)- score.mean())*100)
# Out:
# [ 0.13765061 -8.2841444   0.48483803  0.52301097  0.84248696]
# -1.2592315663628546
# Difference between R2 score and cross validation is :-  13.341858161716413
